# %%
# %matplotlib inline

# %%
import numpy as np
from astropy.io import fits as pyfits
from astropy import wcs
import os, glob, sys
import scipy.interpolate as scint
import scipy.ndimage
import scipy.optimize as scopt

import matplotlib.pyplot as plt

# %% [markdown]
# # METHOD: BIN DOWN IMAGES

# %%
#http://scipy.github.io/old-wiki/pages/Cookbook/Rebinning

def congrid(a, newdims, method='linear', centre=False, minusone=False):
    '''Arbitrary resampling of source array to new dimension sizes.
    Currently only supports maintaining the same number of dimensions.
    To use 1-D arrays, first promote them to shape (x,1).
    
    Uses the same parameters and creates the same co-ordinate lookup points
    as IDL''s congrid routine, which apparently originally came from a VAX/VMS
    routine of the same name.

    method:
    neighbour - closest value from original data
    nearest and linear - uses n x 1-D interpolations using
                         scipy.interpolate.interp1d
    (see Numerical Recipes for validity of use of n 1-D interpolations)
    spline - uses ndimage.map_coordinates

    centre:
    True - interpolation points are at the centres of the bins
    False - points are at the front edge of the bin

    minusone:
    For example- inarray.shape = (i,j) & new dimensions = (x,y)
    False - inarray is resampled by factors of (i/x) * (j/y)
    True - inarray is resampled by(i-1)/(x-1) * (j-1)/(y-1)
    This prevents extrapolation one element beyond bounds of input array.
    '''
    if not a.dtype in [np.float64, np.float32]:
        a = np.cast[float](a)
    
    m1 = np.cast[int](minusone)
    ofs = np.cast[int](centre) * 0.5
    old = np.array( a.shape )
    ndims = len( a.shape )
    if len( newdims ) != ndims:
        print "[congrid] dimensions error. " \
              "This routine currently only support " \
              "rebinning to the same number of dimensions."
        return None
    newdims = np.asarray( newdims, dtype=float )    
    dimlist = []

    if method == 'neighbour':
        for i in range( ndims ):
            base = np.indices(newdims)[i]
            dimlist.append( (old[i] - m1) / (newdims[i] - m1) \
                            * (base + ofs) - ofs )
        cd = np.array( dimlist ).round().astype(int)
        newa = a[list( cd )]
        return newa
    
    elif method in ['nearest','linear']:
        # calculate new dims
        for i in range( ndims ):
            base = np.arange( newdims[i] )
            dimlist.append( (old[i] - m1) / (newdims[i] - m1) \
                            * (base + ofs) - ofs )
        # specify old dims
        olddims = [np.arange(i, dtype = np.float) for i in list( a.shape )]

        # first interpolation - for ndims = any
        mint = scipy.interpolate.interp1d( olddims[-1], a, kind=method )
        newa = mint( dimlist[-1] )

        trorder = [ndims - 1] + range( ndims - 1 )
        for i in range( ndims - 2, -1, -1 ):
            newa = newa.transpose( trorder )

            mint = scipy.interpolate.interp1d( olddims[i], newa, kind=method )
            newa = mint( dimlist[i] )

        if ndims > 1:
            # need one more transpose to return to original dimensions
            newa = newa.transpose( trorder )

        return newa
    elif method in ['spline']:
        oslices = [ slice(0,j) for j in old ]
        oldcoords = np.ogrid[oslices]
        nslices = [ slice(0,j) for j in list(newdims) ]
        newcoords = np.mgrid[nslices]

        newcoords_dims = range(np.rank(newcoords))
        #make first index last
        newcoords_dims.append(newcoords_dims.pop(0))
        newcoords_tr = newcoords.transpose(newcoords_dims)
        # makes a view that affects newcoords

        newcoords_tr += ofs        

        deltas = (np.asarray(old) - m1) / (newdims - m1)
        newcoords_tr *= deltas

        newcoords_tr -= ofs

        newa = scipy.ndimage.map_coordinates(a, newcoords)
        return newa
    else:
        print "Congrid error: Unrecognized interpolation type.\n", \
              "Currently only \'neighbour\', \'nearest\',\'linear\',", \
              "and \'spline\' are supported."
        return None

# %% [markdown]
# # METHOD: READ APT POINTINGS FILE

# %%
def readPointingFile(fname):
    # READ APT POINTINGS FILE AND STRIP DITHERS/BASES:
    
    with open(fname) as f:
        content = f.read().splitlines()
    
    # FIND WHERE EACH OBSERVATION STARTS IN THE POINTINGS FILE:
    obs_start = [iline for iline in xrange(len(content)) if "==============" in content[iline]]
    obs_start.append(len(content))
    
    # GET ALL THE DITHERS FOR EACH OF THE OBSERVATIONS:
    dithers=[]
    for iobs in xrange( len(obs_start[:-1]) ):
        temp = content[obs_start[iobs]:obs_start[iobs+1]]
        
        temp = [x.split() for x in temp] # remove white spaces
        temp = filter(None, temp) # remove empty lines
    
        temp = [x for x in temp if "SCIENCE" in x]
    
        target  = np.array(  [float(i) for i in temp[0][7:9]] )
        dithers.append(np.array( [ [ (float(x[9])+float(x[11])), (float(x[10])-float(x[12])) ] for x in temp] ) )
    
    return target, np.array(dithers)

# %% [markdown]
# # METHODS: CENTER PSF + GENERATE SEGMENT POSITIONS

# %%
def centerPSF(image):
    hdu = pyfits.open(image)#, mode="update")
    sci = hdu[1].data

    com = scipy.ndimage.center_of_mass(sci) 
    com = [int(com[0]), int(com[1])]
    mid = len(sci)/2
        
    PSF = np.roll(sci, mid-com[0], axis=0)
    PSF = np.roll(PSF, mid-com[1], axis=1)
    return PSF


def get_boresight_offset(sigma):
    return  np.random.normal(0., (sigma/np.sqrt(2)), (1,2))


def get_segment_offset(sigma):
    return np.random.normal(0., (sigma/np.sqrt(2)), (18,2))

# %%
def shift_rotate_pts(points, rotation, dec):
    # FOR PLOTTING PURPOSES:
    temp = np.copy(points)
    angle = rotation * np.pi/180.

    points[:,0] = (temp[:,0]*np.cos(angle) - temp[:,1]*np.sin(angle) ) 
    points[:,1] = (temp[:,1]*np.cos(angle) + temp[:,0]*np.sin(angle) )
    
    points[:,0] /= np.cos(dec*np.pi/180.)

    return points


def shift_rotate_SCA(SCA, radangle, target, dither):
    xdith = dither[1]
    ydith = dither[0]

    tempSCA = np.copy(SCA)
    tempSCA[:,0]= SCA[:,0]*np.cos(radangle) - SCA[:,1]*np.sin(radangle) 
    tempSCA[:,1]= SCA[:,0]*np.sin(radangle) + SCA[:,1]*np.cos(radangle)

    xdith = dither[0]*np.sin(radangle) + dither[1]*np.cos(radangle)
    ydith = dither[0]*np.cos(radangle) - dither[1]*np.sin(radangle)

    xdith /= np.cos(target[1]*np.pi/180.)

    SCA[:,0] = tempSCA[:,0] + target[1] + ydith/3600.
    SCA[:,1] = tempSCA[:,1]/np.cos(target[1]*np.pi/180.) + target[0] + xdith/3600.
            
    return SCA

# %% [markdown]
# # CREATE TILE OBJECT

# %%
class NRCtile():
    
        def __init__(self, target, rotation):   
            
            # ARCSECONDS:
            SCAgap  = 5.
            self.SCAwidth= 65.
            MODgap  = 44.
            MODwidth= SCAgap + 2.*self.SCAwidth
            self.radangle = rotation *np.pi/180.

            # DEFINE MIDDLE OF SCA's:
            self.SCA = np.asarray([
                [-MODwidth/2, +MODgap/2+MODwidth],              # A1
                [+SCAgap/2,   +MODgap/2+MODwidth],              # A2
                [-MODwidth/2, +MODgap/2+self.SCAwidth],         # A3
                [+SCAgap/2,   +MODgap/2+self.SCAwidth],         # A4
                [SCAgap/2,    -MODgap/2-self.SCAwidth-SCAgap],  # B1
                [-MODwidth/2, -MODgap/2-self.SCAwidth-SCAgap],  # B2
                [SCAgap/2,    -MODgap/2],                       # B3
                [-MODwidth/2, -MODgap/2]                        # B4
            ]) 
            self.SCA[:,0] += self.SCAwidth/2.
            self.SCA[:,1] -= self.SCAwidth/2.
            
            # CONVERT TO DEGREES:
            self.SCA[:,0]= self.SCA[:,0]/3600. 
            self.SCA[:,1]= self.SCA[:,1]/3600.
        
    
        #
        # THIS IS WHERE ALL THE MAGIC OF CREATING THE MOSAIC HAPPENS:
        # 
        def assignWCS(self, iobs, idither, target, dither, dark, PSFcentered, segment_RADEC, seg_found):
            # Defining function for finding center values:
            linwcs = lambda x, y, n: ((x+y)/2)
            
            bindim = 100
            dither = dither[::-1] 
            PSFcentered = congrid(PSFcentered, [bindim, bindim])
            scaledSCAwidth = self.SCAwidth/np.cos(target[1]*np.pi/180.)
            platescale = 0.032/3600. *(2048./bindim)
            
            SCA = shift_rotate_SCA(np.copy(self.SCA), self.radangle, target, dither)
            
            # LOOP OVER EACH SCA, ASSESS IF THERE SHOULD BE A PSF, ADD ONE IF NECESSARY ELSE USE A DARK:
            iimg = 0
            for isca in xrange( len(self.SCA) ):                
                ipsf = 0
                            
                # DETERMINE RELEVANT WCS HEADER INFORMATION:
                crvalY = SCA[isca,0] 
                crvalX = SCA[isca,1]            
                cdeltaX, cdeltaY = -platescale, platescale
                
                w = wcs.WCS(naxis=2)                           # http://docs.astropy.org/en/latest/wcs/index.html
                w.wcs.crpix = [bindim/2, bindim/2]             # what is the center pixel of the XY grid.
                w.wcs.crval = [crvalX, crvalY]                 # what is the galactic coordinate of that pixel.                
                w.wcs.cdelt = np.array([cdeltaX, cdeltaY])     # what is the pixel scale in lon, lat.
                w.wcs.ctype = ["RA---TAN-SIP", "DEC--TAN-SIP"] # you determine if this is in fact a tangential projection 
                WCShdr = w.to_header()                         # write the HDU object WITH THE HEADER
                                
                cpa = np.cos(self.radangle)
                spa = np.sin(self.radangle)
                WCShdr["CD1_1"] = cdeltaX * cpa
                WCShdr["CD1_2"] = cdeltaY * spa
                WCShdr["CD2_1"] =-cdeltaX * spa
                WCShdr["CD2_2"] = cdeltaY * cpa
            

                # OPEN DARK FITS FILE AND USE AS TEMPLATE:
                fitsfile = dark 
                hdu = pyfits.open(fitsfile)
                
                sci = hdu[1].data/50.  #REDUCE THE ITM NOISE LEVEL IN DARKS
                dq  = hdu[2].data
                prihdr = hdu[0].header
                scihdr = hdu[1].header
                dqhdr  = hdu[2].header
                                
                # BIN DOWN THE IMAGES FOR QUIP TO BE ABLE TO HANDLE:
                sci = congrid(sci, [bindim, bindim])
                dq  = congrid(dq,  [bindim, bindim])


                # RANDOMIZE THE DARK A BIT BY SHIFTING IT RANDOMLY:
                dy, dx = np.random.randint(1,bindim, size=2)
                sci = np.roll(sci, dy, axis=0) # I CAN'T GET THIS TO WORK FOR BOTH AXES AT ONCE:
                sci = np.roll(sci, dx, axis=1)
                
                
                nseg = 0
                tempPSF = np.zeros( (len(sci), len(sci)) )
                for iseg in xrange(len(segment_RADEC)):

                    w = wcs.WCS( scihdr+WCShdr )
                    px, py = w.wcs_world2pix(segment_RADEC[iseg][0], segment_RADEC[iseg][1], 1)
                    
                    # IS THERE A SEGMENT ON THAT SCA?
                    if (0 < px < bindim) and (0< py < bindim): 
                                              
                        # MARK SEGMENT AS CAPTURED BY NIRCAM SCA:
                        if seg_found[iseg]==0: seg_found[iseg]=1
                        print "Found Segment #{:d} on SCA".format(iseg+1)
                        ipsf  = iseg+1
                        nseg += 1
                        mid=len(sci)/2.
                        
                        # BACK OFF FROM SCA EDGE BY A FEW PIXELS TO AVOID ROLL OVER:
                        xedge, yedge = 5,5
                        if px < xedge:        px = xedge
                        if px > bindim-xedge: px = bindim-xedge
                        if py < yedge:        py = yedge
                        if py > bindim-yedge: py = bindim-yedge                            

                        # INJECT THE PSF WHERE IT OUGHT TO BE ON SCA:
                        PSF = np.roll(PSFcentered, int(np.round(py)-mid), axis=0)
                        PSF = np.roll(PSF, int(np.round(px)-mid), axis=1) 
                            
                        tempPSF += PSF

                # IF WE STITCHED MORE THAN ONE PSF ON SAME SCA, NORMALIZE THE TOTAL COUNTS:
                if nseg >= 1: sci = tempPSF/nseg
                
                
                # UPDATE HEADER INFORMATION AND SAVE FILE: 
                prihdr["SUBSIZE1"]=bindim*10
                prihdr["SUBSIZE2"]=bindim
                
                new_hdul = pyfits.HDUList()
                new_hdul.append(pyfits.ImageHDU(header=prihdr+WCShdr))
                new_hdul.append(pyfits.ImageHDU(sci, header=WCShdr, name='SCI'))   
                new_hdul.append(pyfits.ImageHDU(dq , header=WCShdr, name='DQ'))   
                filename = 'Obs{:d}/test{:04d}.fits'.format(iobs,8*idither+iimg)
                if ipsf !=0 : print '   -->', filename
                new_hdul.writeto(filename, clobber=True)     
                hdu.close()
                new_hdul.close()
                
                
                iimg+=1
            
            return seg_found

# %% [markdown]
# # MAIN: INPUTS PARAMETERS

# %%
seed = np.random.randint(10000)
seed = 154
np.random.seed(seed)


imgdir       = "/Users/lajoie/WCS_Test/"
pointingfile = "1134_Mosaic.pointing.txt"
psffile      = "/Users/lajoie/WCS_Test/ITM-OnePSF.fits"
darkfile     = "/Users/lajoie/WCS_Test/ITM-Dark.fits"

os.chdir(imgdir)

target, dithers = readPointingFile(imgdir+pointingfile)
print "Target  :",target

# THIS ANGLE MOVES THE NORTH/EAST AXES CW, OR THE MOSAIC CCW:
rotation = np.random.uniform(0.0, 90.0)
print "Rotation: ",rotation


boresight_sigma = 17.   #3-sigma radial; arcminutes
segments_sigma  = 16.   #3-sigma radial; arcminutes
boresight_offset = get_boresight_offset(boresight_sigma/3.) 
segment_offsets  = get_segment_offset(segments_sigma/3.)
total_offsets = (boresight_offset + segment_offsets)/60.


# THIS ADJUSTMENT, SEEN THROUGHOUT, IS TO ACCOUNT FOR THE FACT 
# THAT AS YOU GO HIGHER IN DECLINATION, A GIVEN ANGULAR 
# SEPARATION RESULTS IN A LARGER R.A. SEPARATION:
total_offsets[:,0] /= np.cos(target[1]*np.pi/180.)
segment_RADEC = target + total_offsets

print len(dithers),'observations in APT file (dithers in arcseconds)'
print "Random seed is:", seed, '\n'
# Out:
# Target  : [ 146.877   63.248]
# Rotation:  45.6951391531
# 7 observations in APT file (dithers in arcseconds)
# Random seed is: 154

# %% [markdown]
# # PLOT DEPLOYED SEGMENTS

# %%
plt.figure(figsize=(6,6))

for i in xrange(18):
    plt.plot(segment_RADEC[i,0], segment_RADEC[i,1], 'ro', markersize=6)
    plt.annotate(str(i+1), xy=(segment_RADEC[i,0], segment_RADEC[i,1]), fontsize=15, ha='center', va='bottom' )

deltadeg = 0.3
plt.xlim( target[0]-deltadeg/np.cos(target[1]*np.pi/180.), target[0]+deltadeg/np.cos(target[1]*np.pi/180.)  )
plt.ylim( target[1]-deltadeg, target[1]+deltadeg )
plt.axvline(x=target[0], color='black', linestyle='--')
plt.axhline(y=target[1], color='black', linestyle='--')

obs1width = 2.2*10./60.
left  = obs1width/2. 
right =-obs1width/2. 
top   = obs1width/2.
bottom=-obs1width/2.

corners = np.array([ [left,top], [left, bottom], [right, bottom], [right, top], [left,top] ])
corners = shift_rotate_pts(corners, -rotation, target[1]) + target

plt.plot(corners[:,0], corners[:,1], color='red', linestyle='--') 
plt.plot(corners[3,0], corners[3,1], 'bo')

plt.xlabel("RA")
plt.ylabel("DEC")
plt.gca().invert_xaxis()
plt.title("Seed {:d}".format(seed))
plt.show()


orient = 0.

deltaDec = (segment_RADEC[:,1]-target[1])
deltaRA  = (segment_RADEC[:,0]-target[0])*np.cos(target[1]*np.pi/180.)
offsets = np.array( zip(deltaRA, deltaDec) )
offsets = shift_rotate_pts(offsets, orient, 0.)*3600.
print "Compare these offsets with APT/Aladin's"
for i in xrange(len(offsets)):
    print i+1, offsets[i] #offsets*3600.
# Out:
# Compare these offsets with APT/Aladin's
# 1 [ 471.61110005  430.8895688 ]
# 2 [ 594.49570014  313.91130994]
# 3 [ 115.08995702  312.5638619 ]
# 4 [ 279.83329989  521.84751028]
# 5 [ 787.05933361  322.13247086]
# 6 [ 401.6720062   311.31997586]
# 7 [ 206.8021078   150.93533154]
# 8 [ 617.98853914  495.61447948]
# 9 [ 395.875616     15.69313821]
# 10 [ 163.83017177  -49.04428622]
# 11 [ 372.3129417   174.15857704]
# 12 [ 542.34308925  455.04196651]
# 13 [ 215.27776868  394.98197675]
# 14 [ 729.35153964  352.26494955]
# 15 [ 404.1167224   119.76539241]
# 16 [ -15.57339571  352.96854372]
# 17 [ 573.21867017  454.51374213]
# 18 [ -34.76275242  212.34168571]

# %% [markdown]
# # MAIN: LOOP OVER EACH OTE-01 OBSERVATION

# %%
seg_found = np.zeros(18)

# %%
tile = NRCtile(target, rotation)

# CHOOSE WHICH OTE-01 OBSERVATION TO EXECUTE (1 to 7):
#       Obs 1: Central
#       Obs 2: East
#       Obs 3: West
#       Obs 4: NorthEast
#       Obs 5: NorthWest
#       Obs 6: SouthEast
#       Obs 7: SouthWest

obs = 5

obs_dithers = dithers[obs-1]
print len(obs_dithers), "pointings"

# THIS IS OUR DEFAULT PSF THAT WE STITCH ON THE MOSAIC WHERE THERE ARE SEGMENTS:
centeredPSF = centerPSF(psffile)


# FOR EACH DITHER POINT, CREATE IMAGES. IF A SEGMENT IS THERE, USE THE centeredPSF:
for i in xrange( len(obs_dithers) ):   
    #print obs_dithers[i]
    seg_found = tile.assignWCS(obs, i, target, obs_dithers[i], darkfile, centeredPSF, segment_RADEC, seg_found)
        
    
print "\nFOUND {:d} SEGMENTS".format(np.count_nonzero(seg_found))
# Out:
# 45 pointings
#
# FOUND 18 SEGMENTS

# %% [markdown]
# # PLOT FOUND/MISSING SEGMENTS

# %%
plt.figure(figsize=(12,12))

for i in xrange(18):
    if seg_found[i]==0: 
        plt.plot(segment_RADEC[i,0], segment_RADEC[i,1], 'ro', markersize=6)
        plt.annotate(str(i+1), xy=(segment_RADEC[i,0], segment_RADEC[i,1]), fontsize=15, ha='center', va='bottom' )
    if seg_found[i]==1: 
        plt.plot(segment_RADEC[i,0], segment_RADEC[i,1], 'go', markersize=6)
        plt.annotate(str(i+1), xy=(segment_RADEC[i,0], segment_RADEC[i,1]), fontsize=15, ha='center', va='bottom')

deltadeg = 0.3
plt.xlim( target[0]-deltadeg/np.cos(target[1]*np.pi/180.), target[0]+deltadeg/np.cos(target[1]*np.pi/180.)  )
plt.ylim( target[1]-deltadeg, target[1]+deltadeg )

plt.plot(corners[:,0], corners[:,1], color='red', linestyle='--') 
plt.plot(corners[3,0], corners[3,1],'bo')

plt.axvline(x=target[0], color='black', linestyle='--')
plt.axhline(y=target[1], color='black', linestyle='--')
plt.gca().invert_xaxis()
plt.xlabel("RA")
plt.ylabel("DEC")
plt.title("Seed {:d}".format(seed))

# %% [markdown]
# # OUTPUT FOR QUIP OPERATION FILE

# %%
for i in xrange(711, 1248):
    print "       <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs{:d}_Rotation/test{:04d}.fits</IMAGE_PATH>".format(obs,i)
# Out:
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0711.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0712.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0713.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0714.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0715.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0716.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0717.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0718.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0719.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0720.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0721.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0722.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0723.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0724.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0725.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0726.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0727.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0728.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0729.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0730.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0731.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0732.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0733.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0734.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0735.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0736.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0737.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0738.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0739.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0740.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0741.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0742.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0743.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0744.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0745.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0746.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0747.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0748.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0749.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0750.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0751.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0752.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0753.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0754.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0755.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0756.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0757.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0758.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0759.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0760.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0761.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0762.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0763.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0764.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0765.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0766.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0767.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0768.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0769.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0770.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0771.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0772.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0773.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0774.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0775.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0776.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0777.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0778.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0779.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0780.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0781.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0782.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0783.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0784.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0785.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0786.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0787.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0788.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0789.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0790.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0791.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0792.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0793.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0794.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0795.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0796.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0797.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0798.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0799.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0800.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0801.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0802.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0803.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0804.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0805.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0806.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0807.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0808.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0809.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0810.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0811.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0812.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0813.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0814.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0815.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0816.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0817.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0818.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0819.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0820.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0821.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0822.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0823.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0824.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0825.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0826.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0827.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0828.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0829.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0830.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0831.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0832.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0833.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0834.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0835.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0836.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0837.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0838.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0839.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0840.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0841.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0842.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0843.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0844.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0845.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0846.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0847.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0848.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0849.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0850.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0851.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0852.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0853.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0854.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0855.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0856.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0857.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0858.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0859.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0860.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0861.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0862.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0863.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0864.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0865.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0866.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0867.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0868.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0869.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0870.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0871.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0872.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0873.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0874.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0875.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0876.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0877.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0878.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0879.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0880.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0881.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0882.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0883.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0884.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0885.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0886.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0887.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0888.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0889.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0890.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0891.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0892.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0893.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0894.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0895.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0896.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0897.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0898.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0899.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0900.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0901.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0902.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0903.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0904.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0905.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0906.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0907.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0908.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0909.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0910.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0911.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0912.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0913.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0914.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0915.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0916.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0917.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0918.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0919.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0920.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0921.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0922.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0923.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0924.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0925.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0926.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0927.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0928.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0929.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0930.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0931.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0932.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0933.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0934.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0935.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0936.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0937.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0938.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0939.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0940.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0941.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0942.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0943.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0944.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0945.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0946.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0947.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0948.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0949.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0950.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0951.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0952.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0953.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0954.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0955.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0956.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0957.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0958.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0959.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0960.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0961.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0962.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0963.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0964.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0965.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0966.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0967.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0968.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0969.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0970.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0971.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0972.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0973.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0974.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0975.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0976.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0977.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0978.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0979.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0980.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0981.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0982.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0983.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0984.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0985.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0986.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0987.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0988.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0989.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0990.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0991.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0992.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0993.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0994.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0995.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0996.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0997.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0998.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test0999.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1000.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1001.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1002.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1003.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1004.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1005.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1006.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1007.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1008.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1009.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1010.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1011.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1012.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1013.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1014.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1015.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1016.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1017.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1018.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1019.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1020.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1021.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1022.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1023.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1024.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1025.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1026.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1027.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1028.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1029.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1030.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1031.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1032.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1033.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1034.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1035.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1036.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1037.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1038.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1039.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1040.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1041.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1042.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1043.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1044.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1045.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1046.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1047.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1048.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1049.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1050.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1051.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1052.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1053.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1054.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1055.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1056.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1057.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1058.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1059.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1060.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1061.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1062.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1063.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1064.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1065.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1066.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1067.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1068.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1069.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1070.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1071.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1072.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1073.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1074.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1075.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1076.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1077.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1078.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1079.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1080.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1081.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1082.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1083.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1084.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1085.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1086.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1087.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1088.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1089.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1090.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1091.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1092.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1093.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1094.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1095.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1096.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1097.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1098.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1099.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1100.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1101.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1102.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1103.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1104.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1105.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1106.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1107.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1108.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1109.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1110.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1111.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1112.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1113.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1114.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1115.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1116.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1117.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1118.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1119.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1120.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1121.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1122.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1123.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1124.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1125.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1126.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1127.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1128.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1129.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1130.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1131.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1132.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1133.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1134.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1135.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1136.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1137.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1138.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1139.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1140.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1141.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1142.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1143.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1144.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1145.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1146.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1147.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1148.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1149.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1150.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1151.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1152.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1153.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1154.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1155.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1156.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1157.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1158.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1159.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1160.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1161.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1162.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1163.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1164.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1165.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1166.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1167.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1168.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1169.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1170.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1171.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1172.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1173.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1174.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1175.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1176.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1177.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1178.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1179.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1180.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1181.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1182.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1183.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1184.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1185.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1186.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1187.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1188.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1189.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1190.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1191.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1192.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1193.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1194.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1195.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1196.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1197.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1198.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1199.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1200.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1201.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1202.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1203.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1204.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1205.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1206.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1207.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1208.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1209.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1210.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1211.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1212.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1213.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1214.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1215.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1216.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1217.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1218.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1219.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1220.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1221.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1222.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1223.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1224.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1225.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1226.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1227.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1228.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1229.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1230.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1231.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1232.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1233.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1234.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1235.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1236.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1237.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1238.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1239.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1240.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1241.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1242.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1243.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1244.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1245.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1246.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/WCS_Test/Obs1_Rotation/test1247.fits</IMAGE_PATH>
