# %%
# %matplotlib inline

# %%
import numpy as np
from astropy.io import fits as pyfits
from astropy import wcs
import os, glob, sys
import scipy.interpolate as scint
import scipy.ndimage
import scipy.optimize as scopt

import matplotlib.pyplot as plt

# %% [markdown]
# # METHOD: BIN DOWN IMAGES

# %%
#http://scipy.github.io/old-wiki/pages/Cookbook/Rebinning

def congrid(a, newdims, method='linear', centre=False, minusone=False):
    '''Arbitrary resampling of source array to new dimension sizes.
    Currently only supports maintaining the same number of dimensions.
    To use 1-D arrays, first promote them to shape (x,1).
    
    Uses the same parameters and creates the same co-ordinate lookup points
    as IDL''s congrid routine, which apparently originally came from a VAX/VMS
    routine of the same name.

    method:
    neighbour - closest value from original data
    nearest and linear - uses n x 1-D interpolations using
                         scipy.interpolate.interp1d
    (see Numerical Recipes for validity of use of n 1-D interpolations)
    spline - uses ndimage.map_coordinates

    centre:
    True - interpolation points are at the centres of the bins
    False - points are at the front edge of the bin

    minusone:
    For example- inarray.shape = (i,j) & new dimensions = (x,y)
    False - inarray is resampled by factors of (i/x) * (j/y)
    True - inarray is resampled by(i-1)/(x-1) * (j-1)/(y-1)
    This prevents extrapolation one element beyond bounds of input array.
    '''
    if not a.dtype in [np.float64, np.float32]:
        a = np.cast[float](a)
    
    m1 = np.cast[int](minusone)
    ofs = np.cast[int](centre) * 0.5
    old = np.array( a.shape )
    ndims = len( a.shape )
    if len( newdims ) != ndims:
        print "[congrid] dimensions error. " \
              "This routine currently only support " \
              "rebinning to the same number of dimensions."
        return None
    newdims = np.asarray( newdims, dtype=float )    
    dimlist = []

    if method == 'neighbour':
        for i in range( ndims ):
            base = np.indices(newdims)[i]
            dimlist.append( (old[i] - m1) / (newdims[i] - m1) \
                            * (base + ofs) - ofs )
        cd = np.array( dimlist ).round().astype(int)
        newa = a[list( cd )]
        return newa
    
    elif method in ['nearest','linear']:
        # calculate new dims
        for i in range( ndims ):
            base = np.arange( newdims[i] )
            dimlist.append( (old[i] - m1) / (newdims[i] - m1) \
                            * (base + ofs) - ofs )
        # specify old dims
        olddims = [np.arange(i, dtype = np.float) for i in list( a.shape )]

        # first interpolation - for ndims = any
        mint = scipy.interpolate.interp1d( olddims[-1], a, kind=method )
        newa = mint( dimlist[-1] )

        trorder = [ndims - 1] + range( ndims - 1 )
        for i in range( ndims - 2, -1, -1 ):
            newa = newa.transpose( trorder )

            mint = scipy.interpolate.interp1d( olddims[i], newa, kind=method )
            newa = mint( dimlist[i] )

        if ndims > 1:
            # need one more transpose to return to original dimensions
            newa = newa.transpose( trorder )

        return newa
    elif method in ['spline']:
        oslices = [ slice(0,j) for j in old ]
        oldcoords = np.ogrid[oslices]
        nslices = [ slice(0,j) for j in list(newdims) ]
        newcoords = np.mgrid[nslices]

        newcoords_dims = range(np.rank(newcoords))
        #make first index last
        newcoords_dims.append(newcoords_dims.pop(0))
        newcoords_tr = newcoords.transpose(newcoords_dims)
        # makes a view that affects newcoords

        newcoords_tr += ofs        

        deltas = (np.asarray(old) - m1) / (newdims - m1)
        newcoords_tr *= deltas

        newcoords_tr -= ofs

        newa = scipy.ndimage.map_coordinates(a, newcoords)
        return newa
    else:
        print "Congrid error: Unrecognized interpolation type.\n", \
              "Currently only \'neighbour\', \'nearest\',\'linear\',", \
              "and \'spline\' are supported."
        return None

# %% [markdown]
# # METHOD: READ APT POINTINGS FILE

# %%
def readPointingFile(fname):
    # READ APT POINTINGS FILE AND STRIP DITHERS/BASES:
    
    with open(fname) as f:
        content = f.read().splitlines()
    
    # FIND WHERE EACH OBSERVATION STARTS IN THE POINTINGS FILE:
    obs_start = [iline for iline in xrange(len(content)) if "==============" in content[iline]]
    obs_start.append(len(content))
    
    # GET ALL THE DITHERS FOR EACH OF THE OBSERVATIONS:
    dithers=[]
    for iobs in xrange( len(obs_start[:-1]) ):
        temp = content[obs_start[iobs]:obs_start[iobs+1]]
        
        temp = [x.split() for x in temp] # remove white spaces
        temp = filter(None, temp) # remove empty lines
    
        temp = [x for x in temp if "SCIENCE" in x]
    
        target  = np.array(  [float(i) for i in temp[0][7:9]] )
        dithers.append(np.array( [ [ (float(x[9])+float(x[11])), (float(x[10])-float(x[12])) ] for x in temp] ) )
    
    return target, np.array(dithers)

# %% [markdown]
# # METHODS: CENTER PSF + GENERATE SEGMENT POSITIONS

# %%
def centerPSF(image):
    hdu = pyfits.open(image)
    sci = hdu[1].data

    com = scipy.ndimage.center_of_mass(sci) 
    com = [int(com[0]), int(com[1])]
    mid = len(sci)/2
        
    PSF = np.roll(sci, mid-com[0], axis=0)
    PSF = np.roll(PSF, mid-com[1], axis=1)
    
    PSF = np.asarray([PSF]*18)
    
    return PSF

def read18PSF(image):
    
    hdu = pyfits.open(image)
    PSF = hdu[0].data
    
    return PSF


def get_boresight_offset(sigma):
    return  np.random.normal(0., (sigma/np.sqrt(2)), (1,2))


def get_segment_offset(sigma):
    return np.random.normal(0., (sigma/np.sqrt(2)), (18,2))

# %%
def shift_rotate_pts(points, rotation, dec):
    # FOR PLOTTING PURPOSES:
    temp = np.copy(points)
    angle = rotation * np.pi/180.

    points[:,0] = (temp[:,0]*np.cos(angle) - temp[:,1]*np.sin(angle) ) 
    points[:,1] = (temp[:,1]*np.cos(angle) + temp[:,0]*np.sin(angle) )
    
    points[:,0] /= np.cos(dec*np.pi/180.)

    return points


def shift_rotate_SCA(SCA, radangle, target, dither):
    xdith = dither[1]
    ydith = dither[0]

    tempSCA = np.copy(SCA)
    tempSCA[:,0]= SCA[:,0]*np.cos(radangle) - SCA[:,1]*np.sin(radangle) 
    tempSCA[:,1]= SCA[:,0]*np.sin(radangle) + SCA[:,1]*np.cos(radangle)

    xdith = dither[0]*np.sin(radangle) + dither[1]*np.cos(radangle)
    ydith = dither[0]*np.cos(radangle) - dither[1]*np.sin(radangle)

    xdith /= np.cos(target[1]*np.pi/180.)

    SCA[:,0] = tempSCA[:,0] + target[1] + ydith/3600.
    SCA[:,1] = tempSCA[:,1]/np.cos(target[1]*np.pi/180.) + target[0] + xdith/3600.
            
    return SCA

# %% [markdown]
# # CREATE TILE OBJECT

# %%
class NRCtile():
    
        def __init__(self, target, rotation):   
            
            # ARCSECONDS:
            SCAgap  = 5.
            self.SCAwidth= 65.
            MODgap  = 44.
            MODwidth= SCAgap + 2.*self.SCAwidth
            self.radangle = rotation *np.pi/180.

            # DEFINE MIDDLE OF SCA's:
            self.SCA = np.asarray([
                [-MODwidth/2, +MODgap/2+MODwidth],              # A1
                [+SCAgap/2,   +MODgap/2+MODwidth],              # A2
                [-MODwidth/2, +MODgap/2+self.SCAwidth],         # A3
                [+SCAgap/2,   +MODgap/2+self.SCAwidth],         # A4
                [SCAgap/2,    -MODgap/2-self.SCAwidth-SCAgap],  # B1
                [-MODwidth/2, -MODgap/2-self.SCAwidth-SCAgap],  # B2
                [SCAgap/2,    -MODgap/2],                       # B3
                [-MODwidth/2, -MODgap/2]                        # B4
            ]) 
            self.SCA[:,0] += self.SCAwidth/2.
            self.SCA[:,1] -= self.SCAwidth/2.
            
            # CONVERT TO DEGREES:
            self.SCA[:,0]= self.SCA[:,0]/3600. 
            self.SCA[:,1]= self.SCA[:,1]/3600.
        
    
        #
        # THIS IS WHERE ALL THE MAGIC OF CREATING THE MOSAIC HAPPENS:
        # 
        def assignWCS(self, iobs, idither, target, dither, dark, PSFcentered, segment_RADEC, seg_found):
            # Defining function for finding center values:
            linwcs = lambda x, y, n: ((x+y)/2)
            
            bindim = 100
            dither = dither[::-1] 
            scaledSCAwidth = self.SCAwidth/np.cos(target[1]*np.pi/180.)
            platescale = 0.032/3600. *(2048./bindim)
            
            SCA = shift_rotate_SCA(np.copy(self.SCA), self.radangle, target, dither)
            
            # LOOP OVER EACH SCA, ASSESS IF THERE SHOULD BE A PSF, ADD ONE IF NECESSARY ELSE USE A DARK:
            iimg = 0
            for isca in xrange( len(self.SCA) ):                
                ipsf = 0
                            
                # DETERMINE RELEVANT WCS HEADER INFORMATION:
                crvalY = SCA[isca,0] 
                crvalX = SCA[isca,1]            
                cdeltaX, cdeltaY = -platescale, platescale
                
                w = wcs.WCS(naxis=2)                           # http://docs.astropy.org/en/latest/wcs/index.html
                w.wcs.crpix = [bindim/2, bindim/2]             # what is the center pixel of the XY grid.
                w.wcs.crval = [crvalX, crvalY]                 # what is the galactic coordinate of that pixel.                
                w.wcs.cdelt = np.array([cdeltaX, cdeltaY])     # what is the pixel scale in lon, lat.
                w.wcs.ctype = ["RA---TAN-SIP", "DEC--TAN-SIP"] # you determine if this is in fact a tangential projection 
                WCShdr = w.to_header()                         # write the HDU object WITH THE HEADER
                                
                cpa = np.cos(self.radangle)
                spa = np.sin(self.radangle)
                WCShdr["CD1_1"] = cdeltaX * cpa
                WCShdr["CD1_2"] = cdeltaY * spa
                WCShdr["CD2_1"] =-cdeltaX * spa
                WCShdr["CD2_2"] = cdeltaY * cpa
            

                # OPEN DARK FITS FILE AND USE AS TEMPLATE:
                fitsfile = dark 
                hdu = pyfits.open(fitsfile)
                
                sci = hdu[1].data/50.  #REDUCE THE ITM NOISE LEVEL IN DARKS
                dq  = hdu[2].data
                prihdr = hdu[0].header
                scihdr = hdu[1].header
                dqhdr  = hdu[2].header
                                
                # BIN DOWN THE IMAGES FOR QUIP TO BE ABLE TO HANDLE:
                sci = congrid(sci, [bindim, bindim])
                dq  = congrid(dq,  [bindim, bindim])


                # RANDOMIZE THE DARK A BIT BY SHIFTING IT RANDOMLY:
                dy, dx = np.random.randint(1,bindim, size=2)
                sci = np.roll(sci, dy, axis=0) # I CAN'T GET THIS TO WORK FOR BOTH AXES AT ONCE:
                sci = np.roll(sci, dx, axis=1)
                
                
                nseg = 0
                tempPSF = np.zeros( (len(sci), len(sci)) )
                for iseg in xrange(len(segment_RADEC)):

                    w = wcs.WCS( scihdr+WCShdr )
                    px, py = w.wcs_world2pix(segment_RADEC[iseg][0], segment_RADEC[iseg][1], 1)
                    
                    # IS THERE A SEGMENT ON THAT SCA?
                    if (0 < px < bindim) and (0< py < bindim): 
                                              
                        # MARK SEGMENT AS CAPTURED BY NIRCAM SCA:
                        if seg_found[iseg]==0: seg_found[iseg]=1
                        print "Found Segment #{:d} on SCA".format(iseg+1)
                        ipsf  = iseg+1
                        nseg += 1
                        mid=len(sci)/2.
                        
                        # BACK OFF FROM SCA EDGE BY A FEW PIXELS TO AVOID ROLL OVER:
                        xedge, yedge = 5,5
                        if px < xedge:        px = xedge
                        if px > bindim-xedge: px = bindim-xedge
                        if py < yedge:        py = yedge
                        if py > bindim-yedge: py = bindim-yedge                            

                        PSF = congrid(PSFcentered[iseg], [bindim, bindim])

                        # INJECT THE PSF WHERE IT OUGHT TO BE ON SCA:
                        PSF = np.roll(PSF, int(np.round(py)-mid), axis=0)
                        PSF = np.roll(PSF, int(np.round(px)-mid), axis=1) 
                            
                        tempPSF += PSF

                # IF WE STITCHED MORE THAN ONE PSF ON SAME SCA, NORMALIZE THE TOTAL COUNTS:
                if nseg >= 1: sci = tempPSF/nseg
                
                
                # UPDATE HEADER INFORMATION AND SAVE FILE: 
                prihdr["SUBSIZE1"]=bindim*10
                prihdr["SUBSIZE2"]=bindim
                
                new_hdul = pyfits.HDUList()
                new_hdul.append(pyfits.ImageHDU(header=prihdr+WCShdr))
                new_hdul.append(pyfits.ImageHDU(sci, header=WCShdr, name='SCI'))   
                new_hdul.append(pyfits.ImageHDU(dq , header=WCShdr, name='DQ'))   
                filename = 'Obs{:d}_offset/test{:04d}.fits'.format(iobs,8*idither+iimg)
                if ipsf !=0 : print '   -->', filename
                new_hdul.writeto(filename, clobber=True)     
                hdu.close()
                new_hdul.close()
                
                
                iimg+=1
            
            return seg_found

# %% [markdown]
# # MAIN: INPUTS PARAMETERS

# %%
seed = np.random.randint(10000)
#seed = 154
np.random.seed(seed)


imgdir       = "/Users/lajoie/TEL/WFSC/tools/"
pointingfile = "1134_Mosaic.pointing.txt"
seglocations = "PSF_location.txt"
psffile      = imgdir+"ITM-OnePSF.fits"
psf18file    = imgdir+"ITM-18PSF.fits"
darkfile     = imgdir+"ITM-Dark.fits"

os.chdir(imgdir)

target, dithers = readPointingFile(imgdir+pointingfile)
print "Target  :",target

# THIS ANGLE MOVES THE NORTH/EAST AXES CW, OR THE MOSAIC CCW:
rotation = 0. # np.random.uniform(0.0, 90.0)
print "Rotation: ",rotation


boresight_sigma = 17.   #3-sigma radial; arcminutes
segments_sigma  = 16.   #3-sigma radial; arcminutes
boresight_offset = get_boresight_offset(boresight_sigma/3.) 

random_segs = False
if random_segs:
    segment_offsets  = get_segment_offset(segments_sigma/3.)
else:
    # READ ACTON'S ITM SEGMENT LOCATIONS INSTEAD:
    x, y = np.loadtxt(seglocations, usecols=(1, 2), unpack=True)
    x = x*0.032/60.
    y = y*0.032/60.
    segment_offsets = np.asarray(zip(x,y))

total_offsets = (boresight_offset + segment_offsets)/60.


# THIS ADJUSTMENT, SEEN THROUGHOUT, IS TO ACCOUNT FOR THE FACT 
# THAT AS YOU GO HIGHER IN DECLINATION, A GIVEN ANGULAR 
# SEPARATION RESULTS IN A LARGER R.A. SEPARATION:
total_offsets[:,0] /= np.cos(target[1]*np.pi/180.)
segment_RADEC = target + total_offsets

print len(dithers),'observations in APT file (dithers in arcseconds)'
print "Random seed is:", seed, '\n'
# Out:
# Target  : [ 146.877   63.248]
# Rotation:  0.0
# 7 observations in APT file (dithers in arcseconds)
# Random seed is: 9937

# %%
print boresight_offset
# Out:
# [[ 3.45037987  2.71885817]]

# %% [markdown]
# # PLOT DEPLOYED SEGMENTS

# %%
plt.figure(figsize=(6,6))

for i in xrange(18):
    plt.plot(segment_RADEC[i,0], segment_RADEC[i,1], 'ro', markersize=6)
    plt.annotate(str(i+1), xy=(segment_RADEC[i,0], segment_RADEC[i,1]), fontsize=15, ha='center', va='bottom' )

deltadeg = 0.3
plt.xlim( target[0]-deltadeg/np.cos(target[1]*np.pi/180.), target[0]+deltadeg/np.cos(target[1]*np.pi/180.)  )
plt.ylim( target[1]-deltadeg, target[1]+deltadeg )
plt.axvline(x=target[0], color='black', linestyle='--')
plt.axhline(y=target[1], color='black', linestyle='--')

obs1width = 2.2*10./60.
left  = obs1width/2. 
right =-obs1width/2. 
top   = obs1width/2.
bottom=-obs1width/2.

corners = np.array([ [left,top], [left, bottom], [right, bottom], [right, top], [left,top] ])
corners = shift_rotate_pts(corners, -rotation, target[1]) + target

plt.plot(corners[:,0], corners[:,1], color='red', linestyle='--') 
plt.plot(corners[3,0], corners[3,1], 'bo')

plt.xlabel("RA")
plt.ylabel("DEC")
plt.gca().invert_xaxis()
plt.title("Seed {:d}".format(seed))
plt.show()


orient = 0.

deltaDec = (segment_RADEC[:,1]-target[1])
deltaRA  = (segment_RADEC[:,0]-target[0])*np.cos(target[1]*np.pi/180.)
offsets = np.array( zip(deltaRA, deltaDec) )
offsets = shift_rotate_pts(offsets, orient, 0.)*3600.
print "Compare these offsets with APT/Aladin's"
for i in xrange(len(offsets)):
    print i+1, offsets[i] #offsets*3600.
# Out:
# Compare these offsets with APT/Aladin's
# 1 [ 257.30247233  188.61357039]
# 2 [ 118.57799233  150.29619439]
# 3 [ 127.53831233  139.77939439]
# 4 [ 216.51735233  209.06493039]
# 5 [ 239.52775233  140.12393839]
# 6 [ 386.66471233  186.56009839]
# 7 [ 196.51159233  361.53565039]
# 8 [ 143.18855233  259.97693039]
# 9 [ 363.91975233  208.98589039]
# 10 [ 334.61479233  181.86128239]
# 11 [ 375.74471233   74.40541039]
# 12 [ 265.83431233   58.12541039]
# 13 [ 133.25479233  -21.13378961]
# 14 [ 216.00032833   56.95325039]
# 15 [   9.15175233  254.31197039]
# 16 [  95.74407233  118.71357039]
# 17 [  57.78311233  191.36742639]
# 18 [ 188.08196033  175.51286639]

# %% [markdown]
# # MAIN: LOOP OVER EACH OTE-01 OBSERVATION

# %%
seg_found = np.zeros(18)

# %%
tile = NRCtile(target, rotation)

# CHOOSE WHICH OTE-01 OBSERVATION TO EXECUTE (1 to 7):
#       Obs 1: Central
#       Obs 2: East
#       Obs 3: West
#       Obs 4: NorthEast
#       Obs 5: NorthWest
#       Obs 6: SouthEast
#       Obs 7: SouthWest

obs = 1

obs_dithers = dithers[obs-1]
print len(obs_dithers), "pointings"

# THIS IS OUR DEFAULT PSF THAT WE STITCH ON THE MOSAIC WHERE THERE ARE SEGMENTS:
if random_segs: 
    centeredPSF = centerPSF(psffile)
else: 
    centeredPSF = read18PSF(psf18file)



# FOR EACH DITHER POINT, CREATE IMAGES. IF A SEGMENT IS THERE, USE THE centeredPSF:
for i in xrange( len(obs_dithers) ):   
    #print obs_dithers[i]
    seg_found = tile.assignWCS(obs, i, target, obs_dithers[i], darkfile, centeredPSF, segment_RADEC, seg_found)
        
    
print "\nFOUND {:d} SEGMENTS".format(np.count_nonzero(seg_found))
# Out:
# 156 pointings
# Found Segment #7 on SCA
#    --> Obs1_offset/test0337.fits
# Found Segment #7 on SCA
#    --> Obs1_offset/test0347.fits
# Found Segment #8 on SCA
#    --> Obs1_offset/test0351.fits
# Found Segment #8 on SCA
#    --> Obs1_offset/test0357.fits
# Found Segment #7 on SCA
#    --> Obs1_offset/test0358.fits
# Found Segment #17 on SCA
#    --> Obs1_offset/test0424.fits
# Found Segment #15 on SCA
#    --> Obs1_offset/test0427.fits
# Found Segment #18 on SCA
#    --> Obs1_offset/test0432.fits
# Found Segment #2 on SCA
#    --> Obs1_offset/test0434.fits
# Found Segment #15 on SCA
#    --> Obs1_offset/test0438.fits
# Found Segment #4 on SCA
# Found Segment #18 on SCA
#    --> Obs1_offset/test0442.fits
# Found Segment #15 on SCA
#    --> Obs1_offset/test0444.fits
# Found Segment #17 on SCA
#    --> Obs1_offset/test0445.fits
# Found Segment #8 on SCA
#    --> Obs1_offset/test0446.fits
# Found Segment #2 on SCA
#    --> Obs1_offset/test0447.fits
# Found Segment #6 on SCA
#    --> Obs1_offset/test0448.fits
# Found Segment #10 on SCA
#    --> Obs1_offset/test0450.fits
# Found Segment #8 on SCA
#    --> Obs1_offset/test0452.fits
# Found Segment #4 on SCA
#    --> Obs1_offset/test0455.fits
# Found Segment #1 on SCA
#    --> Obs1_offset/test0461.fits
# Found Segment #9 on SCA
# Found Segment #10 on SCA
#    --> Obs1_offset/test0463.fits
# Found Segment #6 on SCA
# Found Segment #9 on SCA
#    --> Obs1_offset/test0469.fits
# Found Segment #16 on SCA
#    --> Obs1_offset/test0521.fits
# Found Segment #18 on SCA
#    --> Obs1_offset/test0529.fits
# Found Segment #2 on SCA
# Found Segment #3 on SCA
# Found Segment #16 on SCA
#    --> Obs1_offset/test0531.fits
# Found Segment #12 on SCA
#    --> Obs1_offset/test0536.fits
# Found Segment #14 on SCA
#    --> Obs1_offset/test0538.fits
# Found Segment #5 on SCA
# Found Segment #18 on SCA
#    --> Obs1_offset/test0539.fits
# Found Segment #2 on SCA
# Found Segment #3 on SCA
# Found Segment #16 on SCA
#    --> Obs1_offset/test0542.fits
# Found Segment #11 on SCA
#    --> Obs1_offset/test0544.fits
# Found Segment #3 on SCA
#    --> Obs1_offset/test0548.fits
# Found Segment #5 on SCA
#    --> Obs1_offset/test0550.fits
# Found Segment #14 on SCA
#    --> Obs1_offset/test0551.fits
# Found Segment #5 on SCA
#    --> Obs1_offset/test0556.fits
# Found Segment #12 on SCA
#    --> Obs1_offset/test0557.fits
# Found Segment #11 on SCA
#    --> Obs1_offset/test0565.fits
# Found Segment #13 on SCA
#    --> Obs1_offset/test0626.fits
# Found Segment #12 on SCA
#    --> Obs1_offset/test0633.fits
# Found Segment #14 on SCA
#    --> Obs1_offset/test0635.fits
# Found Segment #13 on SCA
#    --> Obs1_offset/test0639.fits
# Found Segment #13 on SCA
#    --> Obs1_offset/test0645.fits
# Found Segment #14 on SCA
#    --> Obs1_offset/test0646.fits
# Found Segment #12 on SCA
#    --> Obs1_offset/test0652.fits
#
# FOUND 18 SEGMENTS

# %% [markdown]
# # PLOT FOUND/MISSING SEGMENTS

# %%
plt.figure(figsize=(12,12))

for i in xrange(18):
    if seg_found[i]==0: 
        plt.plot(segment_RADEC[i,0], segment_RADEC[i,1], 'ro', markersize=6)
        plt.annotate(str(i+1), xy=(segment_RADEC[i,0], segment_RADEC[i,1]), fontsize=15, ha='center', va='bottom' )
    if seg_found[i]==1: 
        plt.plot(segment_RADEC[i,0], segment_RADEC[i,1], 'go', markersize=6)
        plt.annotate(str(i+1), xy=(segment_RADEC[i,0], segment_RADEC[i,1]), fontsize=15, ha='center', va='bottom')

deltadeg = 0.3
plt.xlim( target[0]-deltadeg/np.cos(target[1]*np.pi/180.), target[0]+deltadeg/np.cos(target[1]*np.pi/180.)  )
plt.ylim( target[1]-deltadeg, target[1]+deltadeg )

plt.plot(corners[:,0], corners[:,1], color='red', linestyle='--') 
plt.plot(corners[3,0], corners[3,1],'bo')

plt.axvline(x=target[0], color='black', linestyle='--')
plt.axhline(y=target[1], color='black', linestyle='--')
plt.gca().invert_xaxis()
plt.xlabel("RA")
plt.ylabel("DEC")
plt.title("Seed {:d}".format(seed))

# %% [markdown]
# # OUTPUT FOR QUIP OPERATION FILE

# %%
for i in xrange(1, 1248):
    print "       <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs{:d}_Rotation/test{:04d}.fits</IMAGE_PATH>".format(obs,i)
# Out:
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0001.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0002.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0003.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0004.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0005.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0006.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0007.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0008.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0009.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0010.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0011.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0012.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0013.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0014.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0015.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0016.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0017.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0018.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0019.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0020.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0021.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0022.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0023.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0024.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0025.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0026.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0027.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0028.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0029.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0030.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0031.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0032.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0033.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0034.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0035.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0036.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0037.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0038.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0039.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0040.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0041.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0042.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0043.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0044.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0045.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0046.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0047.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0048.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0049.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0050.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0051.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0052.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0053.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0054.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0055.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0056.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0057.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0058.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0059.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0060.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0061.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0062.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0063.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0064.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0065.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0066.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0067.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0068.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0069.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0070.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0071.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0072.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0073.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0074.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0075.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0076.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0077.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0078.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0079.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0080.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0081.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0082.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0083.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0084.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0085.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0086.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0087.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0088.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0089.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0090.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0091.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0092.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0093.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0094.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0095.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0096.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0097.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0098.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0099.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0100.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0101.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0102.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0103.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0104.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0105.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0106.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0107.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0108.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0109.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0110.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0111.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0112.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0113.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0114.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0115.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0116.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0117.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0118.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0119.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0120.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0121.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0122.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0123.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0124.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0125.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0126.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0127.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0128.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0129.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0130.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0131.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0132.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0133.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0134.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0135.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0136.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0137.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0138.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0139.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0140.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0141.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0142.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0143.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0144.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0145.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0146.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0147.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0148.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0149.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0150.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0151.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0152.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0153.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0154.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0155.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0156.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0157.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0158.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0159.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0160.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0161.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0162.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0163.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0164.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0165.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0166.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0167.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0168.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0169.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0170.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0171.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0172.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0173.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0174.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0175.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0176.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0177.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0178.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0179.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0180.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0181.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0182.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0183.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0184.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0185.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0186.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0187.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0188.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0189.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0190.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0191.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0192.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0193.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0194.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0195.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0196.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0197.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0198.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0199.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0200.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0201.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0202.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0203.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0204.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0205.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0206.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0207.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0208.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0209.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0210.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0211.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0212.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0213.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0214.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0215.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0216.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0217.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0218.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0219.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0220.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0221.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0222.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0223.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0224.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0225.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0226.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0227.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0228.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0229.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0230.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0231.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0232.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0233.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0234.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0235.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0236.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0237.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0238.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0239.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0240.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0241.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0242.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0243.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0244.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0245.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0246.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0247.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0248.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0249.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0250.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0251.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0252.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0253.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0254.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0255.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0256.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0257.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0258.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0259.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0260.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0261.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0262.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0263.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0264.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0265.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0266.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0267.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0268.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0269.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0270.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0271.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0272.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0273.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0274.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0275.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0276.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0277.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0278.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0279.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0280.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0281.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0282.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0283.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0284.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0285.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0286.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0287.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0288.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0289.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0290.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0291.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0292.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0293.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0294.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0295.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0296.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0297.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0298.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0299.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0300.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0301.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0302.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0303.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0304.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0305.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0306.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0307.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0308.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0309.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0310.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0311.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0312.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0313.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0314.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0315.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0316.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0317.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0318.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0319.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0320.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0321.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0322.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0323.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0324.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0325.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0326.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0327.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0328.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0329.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0330.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0331.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0332.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0333.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0334.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0335.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0336.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0337.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0338.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0339.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0340.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0341.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0342.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0343.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0344.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0345.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0346.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0347.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0348.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0349.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0350.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0351.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0352.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0353.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0354.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0355.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0356.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0357.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0358.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0359.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0360.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0361.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0362.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0363.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0364.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0365.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0366.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0367.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0368.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0369.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0370.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0371.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0372.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0373.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0374.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0375.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0376.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0377.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0378.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0379.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0380.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0381.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0382.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0383.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0384.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0385.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0386.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0387.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0388.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0389.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0390.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0391.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0392.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0393.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0394.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0395.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0396.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0397.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0398.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0399.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0400.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0401.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0402.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0403.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0404.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0405.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0406.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0407.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0408.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0409.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0410.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0411.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0412.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0413.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0414.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0415.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0416.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0417.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0418.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0419.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0420.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0421.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0422.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0423.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0424.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0425.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0426.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0427.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0428.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0429.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0430.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0431.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0432.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0433.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0434.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0435.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0436.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0437.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0438.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0439.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0440.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0441.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0442.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0443.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0444.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0445.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0446.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0447.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0448.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0449.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0450.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0451.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0452.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0453.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0454.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0455.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0456.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0457.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0458.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0459.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0460.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0461.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0462.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0463.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0464.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0465.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0466.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0467.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0468.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0469.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0470.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0471.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0472.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0473.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0474.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0475.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0476.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0477.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0478.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0479.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0480.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0481.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0482.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0483.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0484.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0485.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0486.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0487.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0488.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0489.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0490.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0491.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0492.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0493.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0494.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0495.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0496.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0497.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0498.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0499.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0500.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0501.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0502.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0503.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0504.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0505.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0506.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0507.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0508.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0509.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0510.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0511.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0512.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0513.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0514.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0515.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0516.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0517.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0518.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0519.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0520.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0521.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0522.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0523.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0524.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0525.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0526.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0527.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0528.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0529.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0530.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0531.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0532.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0533.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0534.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0535.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0536.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0537.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0538.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test0539.fits</IMAGE_PATH>
# ...
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1069.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1070.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1071.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1072.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1073.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1074.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1075.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1076.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1077.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1078.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1079.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1080.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1081.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1082.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1083.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1084.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1085.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1086.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1087.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1088.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1089.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1090.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1091.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1092.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1093.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1094.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1095.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1096.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1097.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1098.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1099.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1100.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1101.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1102.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1103.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1104.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1105.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1106.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1107.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1108.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1109.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1110.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1111.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1112.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1113.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1114.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1115.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1116.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1117.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1118.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1119.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1120.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1121.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1122.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1123.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1124.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1125.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1126.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1127.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1128.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1129.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1130.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1131.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1132.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1133.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1134.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1135.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1136.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1137.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1138.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1139.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1140.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1141.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1142.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1143.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1144.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1145.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1146.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1147.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1148.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1149.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1150.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1151.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1152.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1153.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1154.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1155.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1156.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1157.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1158.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1159.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1160.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1161.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1162.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1163.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1164.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1165.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1166.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1167.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1168.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1169.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1170.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1171.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1172.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1173.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1174.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1175.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1176.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1177.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1178.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1179.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1180.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1181.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1182.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1183.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1184.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1185.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1186.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1187.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1188.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1189.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1190.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1191.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1192.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1193.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1194.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1195.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1196.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1197.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1198.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1199.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1200.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1201.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1202.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1203.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1204.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1205.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1206.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1207.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1208.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1209.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1210.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1211.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1212.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1213.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1214.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1215.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1216.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1217.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1218.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1219.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1220.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1221.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1222.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1223.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1224.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1225.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1226.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1227.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1228.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1229.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1230.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1231.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1232.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1233.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1234.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1235.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1236.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1237.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1238.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1239.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1240.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1241.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1242.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1243.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1244.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1245.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1246.fits</IMAGE_PATH>
#        <IMAGE_PATH>/Users/lajoie/TEL/WFSC/tools/Obs1_Rotation/test1247.fits</IMAGE_PATH>
